# %% [markdown]
# ### Tratamento e Limpeza da base - AliPaga

# %%
import pandas as pd
import numpy as np
import seaborn as sns
pd.set_option('display.float_format', '{:.2f}'.format) 
#Comando para evitar notações cientificas, nº grandes

# %%
# Importando CSV
store = pd.read_csv('superstore_dataset2011-2015.csv',error_bad_lines=False, delimiter= ',',
                    encoding='ISO-8859-1',thousands=",", decimal=".")

# %%
store.head(5)
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
store.tail(5)
# Out:
#        Row ID        Order ID  Order Date Ship Date       Ship Mode  \
# 51285   32593  CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594    MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857  MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852  MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388  CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name    Segment       City             State  \
# 51285    EB-13975        Erica Bern  Corporate  Fairfield        California
# 51286     LP-7095         Liz Preis   Consumer     Agadir  Souss-Massa-Draâ
# 51287    CM-12190  Charlotte Melton   Consumer    Managua           Managua
# 51288    TD-20995     Tamara Dahlen   Consumer     Juárez         Chihuahua
# 51289    JM-15580     Jill Matthias   Consumer   Loveland          Colorado
#
#        ...        Product ID         Category Sub-Category  \
# ...

# %%
store.shape
# Out:
# (51290, 24)

# %%
store.index
# Out:
# RangeIndex(start=0, stop=51290, step=1)

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
store.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
store.columns.values
# Out:
# array(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State',
#        'Country', 'Postal Code', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype=object)

# %%
column_names=['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
       'Customer ID', 'Customer Name', 'Segment', 'City', 'State',
       'Country', 'Postal Code', 'Market', 'Region', 'Product ID',
       'Category', 'Sub-Category', 'Product Name', 'Quantity',
       'Discount', 'Profit', 'Shipping Cost', 'Order Priority','Sales']

# %%
store=store[column_names]

# %%
store.head(3)
# Out:
#    Row ID       Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433   AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253  IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883   HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
#
#      Customer Name   Segment         City            State  ...  \
# 0  Toby Braunhardt  Consumer  Constantine      Constantine  ...
# 1      Joseph Holt  Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman  Consumer     Budapest         Budapest  ...
#
#          Product ID         Category Sub-Category              Product Name  \
# 0  OFF-TEN-10000025  Office Supplies      Storage       Tenex Lockers, Blue
# 1   OFF-SU-10000618  Office Supplies     Supplies  Acme Trimmer, High Speed
# 2  OFF-TEN-10001585  Office Supplies      Storage   Tenex Box, Single Width
#
#   Quantity Discount Profit Shipping Cost  Order Priority  Sales
# ...

# %%
store['Postal Code']
# Out:
# 0            nan
# 1            nan
# 2            nan
# 3            nan
# 4            nan
#           ...
# 51285   94533.00
# 51286        nan
# 51287        nan
# 51288        nan
# 51289   80538.00
# Name: Postal Code, Length: 51290, dtype: float64

# %%
store.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
store.drop(['Row ID','Order ID','Customer ID','Product ID','Postal Code','Ship Mode'],axis=1,inplace=True)
store.head()
# Out:
#   Order Date Ship Date    Customer Name      Segment         City  \
# 0   1/1/2011  6/1/2011  Toby Braunhardt     Consumer  Constantine
# 1   1/1/2011  8/1/2011      Joseph Holt     Consumer  Wagga Wagga
# 2   1/1/2011  5/1/2011    Annie Thurman     Consumer     Budapest
# 3   1/1/2011  5/1/2011     Eugene Moren  Home Office    Stockholm
# 4   1/1/2011  8/1/2011      Joseph Holt     Consumer  Wagga Wagga
#
#              State    Country  Market   Region         Category Sub-Category  \
# 0      Constantine    Algeria  Africa   Africa  Office Supplies      Storage
# 1  New South Wales  Australia    APAC  Oceania  Office Supplies     Supplies
# 2         Budapest    Hungary    EMEA     EMEA  Office Supplies      Storage
# 3        Stockholm     Sweden      EU    North  Office Supplies        Paper
# 4  New South Wales  Australia    APAC  Oceania        Furniture  Furnishings
#
#                   Product Name  Quantity  Discount  Profit  Shipping Cost  \
# ...

# %%
store.describe()
# Out:
#        Quantity  Discount   Profit  Shipping Cost    Sales
# count  51290.00  51290.00 51290.00       51290.00 51290.00
# mean       3.48      0.14    28.61          26.38   246.49
# std        2.28      0.21   174.34          57.30   487.57
# min        1.00      0.00 -6599.98           0.00     0.44
# 25%        2.00      0.00     0.00           2.61    30.76
# 50%        3.00      0.00     9.24           7.79    85.05
# 75%        5.00      0.20    36.81          24.45   251.05
# max       14.00      0.85  8399.98         933.57 22638.48

# %%
store.nunique()
# Out:
# Order Date         1430
# Ship Date          1464
# Customer Name       795
# Segment               3
# City               3636
# State              1094
# Country             147
# Market                7
# Region               13
# Category              3
# Sub-Category         17
# Product Name       3788
# Quantity             14
# Discount             27
# Profit            24575
# Shipping Cost     10037
# Order Priority        4
# Sales             22995
# dtype: int64

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dados = store
dados.head(3)
# Out:
#   Order Date Ship Date    Customer Name   Segment         City  \
# 0   1/1/2011  6/1/2011  Toby Braunhardt  Consumer  Constantine
# 1   1/1/2011  8/1/2011      Joseph Holt  Consumer  Wagga Wagga
# 2   1/1/2011  5/1/2011    Annie Thurman  Consumer     Budapest
#
#              State    Country  Market   Region         Category Sub-Category  \
# 0      Constantine    Algeria  Africa   Africa  Office Supplies      Storage
# 1  New South Wales  Australia    APAC  Oceania  Office Supplies     Supplies
# 2         Budapest    Hungary    EMEA     EMEA  Office Supplies      Storage
#
#                Product Name  Quantity  Discount  Profit  Shipping Cost  \
# 0       Tenex Lockers, Blue         2      0.00  106.14          35.46
# 1  Acme Trimmer, High Speed         3      0.10   36.04           9.72
# 2   Tenex Box, Single Width         4      0.00   29.64           8.17
#
#   Order Priority  Sales
# 0         Medium 408.30
# 1         Medium 120.37
# 2           High  66.12

# %%
dados.to_csv('dados.csv', index=False)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\marco\\Documents\\Python trabalhos\\ABRACD\\Desafio James Delivery'

# %%
import os

cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in 'C:\\Users\\marco\\Documents\\Python trabalhos\\ABRACD\\Desafio James Delivery': ['.ipynb_checkpoints', '1. Tratamento e Limpeza da base - Superstore.ipynb', 'archive - alipaga.zip', 'Caso de Data Science (1).docx', 'dados.csv', 'retail-sales-forecasting-machine-learning.ipynb', 'retail-superstore-eda.ipynb', 'superstore_dataset2011-2015.csv']

# %%
import os
 
path_name = "dados.csv"
 
if os.path.exists(path_name):
  print("File exists")
else:
  print("File does not exist")
# Out:
# File exists
